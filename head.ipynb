# %% [markdown]
# <a href="https://colab.research.google.com/github/wbh-wkl/Pandas/blob/main/head.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
    'Score': [85, 90, 95, 88, 92, 87]
}

df = pd.DataFrame(data)

# %%
print(df)
# Out:
#       Name  Score
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     95
# 3    David     88
# 4      Eva     92
# 5    Frank     87

# %%
df.head()
# Out:
#       Name  Score
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     95
# 3    David     88
# 4      Eva     92
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Score'].plot(kind='hist', bins=20, title='Score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
df.head(3)
# Out:
#       Name  Score
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     95
